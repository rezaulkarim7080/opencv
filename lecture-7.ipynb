# %% [markdown]
# ### Template for image open

# %%
import cv2
import numpy as np

#read image 
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 42.png")
img = cv2.resize(img,(800,600))

cv2.imshow("Original image",img)
cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ## drawing Function with opencv and numpy

# %% [markdown]
# ![drawing on image.jpg](<attachment:drawing on image.jpg>)

# %%
import numpy as np
import cv2

#comment  image type --1

img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 47.png")
img = cv2.resize(img,(800,600))


#or comment image type --2

#Blank image generate or black image numpy with zeros
# img = np.zeros([512,512,3],np.uint8)*255 # for black color 0
# img = np.ones([512,512,3],np.uint8)*255 # for white color 1



#here line accept 5 parametere (img,starting ,ending ,color, thickness)

img =cv2.line(img,(0,0),(200,200),(5, 98, 247),10) #color format BRG
img =cv2.line(img,(30,60),(200,200),(252, 253, 255),10) #color format BRG

img =cv2.rectangle(img,(100,100),(300,300),(252, 253, 255),-1) #outline rectangle Color
img =cv2.rectangle(img,(300,300),(500,500),(252, 253, 255),10) #rectangle Color

img =cv2.circle(img,(400,500),50,(255, 25, 25),10) #circle Color
img =cv2.circle(img,(400,500),50,(255, 25, 25),-5) #circle Color

#Arrored line accept 5 parametere (img,starting ,ending ,color, thickness)
img =cv2.arrowedLine(img,(0,125),(200,500),(5, 98, 150),30) #color format BRG


#putText line accept 5 parametere (img,text,starting ,fontsize ,color, thickness,linetype)
font = cv2.FONT_ITALIC
img =cv2.putText(img,"This is text",(20,100),font,4,(255, 247, 247),10,cv2.LINE_AA) #color format BRG


# Draw an ellipse
# cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, thickness, lineType, shift=0)
cv2.ellipse(img, (256, 256), (100, 50), 0, 0, 180, 255, -1)


# Draw a yellow polyline (a series of connected line segments)
# cv2.polylines(img, pts, isClosed, color, thickness=1, lineType=cv2.LINE_8, shift=0)
pts = np.array([[10, 5], [20, 30], [70, 20], [50, 10]], np.int32)
pts = pts.reshape((-1, 1, 2))
cv2.polylines(img, [pts], True, (0, 255, 255), 2)


cv2.imshow("res",img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %% [markdown]
# ## drawing on video Function with opencv and numpy

# %% [markdown]
# ![write on video.jpg](<attachment:write on video.jpg>)

# %%
import datetime
import cv2


# cap = cv2.VideoCapture(0)  #for opening Webcamra 
cap = cv2.VideoCapture("D:\\Video\\50 Entrepreneurs share priceless advice.mp4")

# print(" width of the video == ",cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# print(" height of the video== ",cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
# ------------------------OR ---------------------------
print(" width of the video == ",cap.get(3))
print(" height of the video== ",cap.get(4))



while(cap.isOpened()):
    ret,frame = cap.read()
    if ret == True:
        
        # show text 
        font = cv2.FONT_HERSHEY_COMPLEX_SMALL
        #putText line accept 5 parametere (video,text,starting ,fontsize ,color, thickness,linetype)
        text = "Height :" + str(cap.get(4)) + "  width : " + str(cap.get(3))
        frame =cv2.putText(frame,text,(0,450),font,2,(255, 0, 21),1,cv2.LINE_AA) 

        #show real date 
        date_data = "Date " + str(datetime.datetime.now())
        frame =cv2.putText(frame,date_data,(0,50),font,2,(255, 255, 255),1,cv2.LINE_AA) 
        
        #rectanlge like image 
        frame =cv2.rectangle(frame,(300,300),(500,500),(252, 253, 255),10)


        cv2.imshow('frame',frame)

        if cv2.waitKey(30) & 0xFF == ord("s"):
         break
    else:
        break

cap.release()
cv2.destroyAllWindows();
# Out:
#  width of the video ==  854.0
#  height of the video==  480.0

# %% [markdown]
# ## lecture-8

# %% [markdown]
# ### Binding Mouse Events With Opencv Functions

# %% [markdown]
# ![Screenshot_1.jpg](attachment:Screenshot_1.jpg)

# %%
import cv2
import numpy as np


def draw(event,x,y,flags,param):
    print(" x== ",x)
    print("y == ",y)
    print("flags == ",flags)
    print("param == ",param)

    if event == cv2.EVENT_LBUTTONDBLCLK:
        cv2.circle(img,(x,y),50,(255, 25, 25),5)
    if event == cv2.EVENT_RBUTTONDBLCLK:
        cv2.rectangle(img,(x,y),(x+100,y+75),(252, 253, 255),3)

cv2.namedWindow(winname = "res")

img = np.zeros((512,512,3),np.uint8)
cv2.setMouseCallback("res",draw)

while True:
    cv2.imshow("res",img)

    if cv2.waitKey(30) & 0xFF == ord("s"):
         break

cv2.destroyAllWindows();

# %% [markdown]
# ### create a function whcih help to find cordinate of any pixel its color

# %% [markdown]
# ![pick color.jpg](<attachment:pick color.jpg>)

# %%
import cv2
import numpy as np


def mouse_Event(event,x,y,flags,param):
    print(" x== ",x)
    print("y == ",y)
    print("flags == ",flags)
    print("param == ",param)

    font = cv2.FONT_HERSHEY_COMPLEX_SMALL

    if event == cv2.EVENT_LBUTTONDOWN:
        print(x,",",y)
        cord = "cord(x,y) . "+str(x) + ", "+str(y)
        cv2.putText(img,cord,(x,y),font,2,(255, 0, 21),2) 
        # cv2.imshow("image",img)

    if event == cv2.EVENT_RBUTTONDOWN:
        b= img[y , x, 0] #for the blue channel is 0
        g= img[y , x, 1] #for the green channel is 1
        r= img[y , x, 2] #for the red channel is 2

        color_bgr = "rgb(r,g,b) . " + str(b) + ", " + str(g)+ ", "+str(r)
        cv2.putText(img,color_bgr,(x,y),font,2,(255, 250, 250),2) 
        # cv2.imshow("image",img)


cv2.namedWindow(winname = "res")

# img = np.zeros((512,512,3),np.uint8)
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 22.png")
img = cv2.resize(img,(800,600))
cv2.setMouseCallback("res",mouse_Event)


while True:
    cv2.imshow("res",img)

    if cv2.waitKey(30) & 0xFF == ord("s"):
         break

cv2.destroyAllWindows();

# %% [markdown]
# ### COLOR PICKER USING TRACKBARS

# %% [markdown]
# ![color picker.jpg](<attachment:color picker.jpg>)

# %%
import cv2
import numpy as np

def cross(x):
    pass

#blank artboard
img = np.zeros((512,512,3),np.uint8)
cv2.namedWindow("Color Picker")
# img = cv2.resize(img,(1000,800))

#create switch
s1 = "0:OFF\n1:ON"
cv2.createTrackbar(s1,"Color Picker",0,1,cross)

#creating for rgb
cv2.createTrackbar("R","Color Picker",0,255,cross)
cv2.createTrackbar("G","Color Picker",0,255,cross)
cv2.createTrackbar("B","Color Picker",0,255,cross)


while True:
    cv2.imshow("Color Picker",img)
    k = cv2.waitKey(1) & 0xFF
    if k==27: #for exit
        break
         

    # now get trackbar pos
    s = cv2.getTrackbarPos(s1,"Color Picker")
    r = cv2.getTrackbarPos("R","Color Picker")
    g = cv2.getTrackbarPos("G","Color Picker")
    b = cv2.getTrackbarPos("B","Color Picker")


    if s == 0:
        img[:] = 0
    else:
        img[:] = [r,g,b]

cv2.destroyAllWindows();

# %% [markdown]
# ## IMAGE PROCECCING FUNCTIOS

# %% [markdown]
# #### Image Operation eith pixels and cordinates --

# %% [markdown]
# ![split.jpg](attachment:split.jpg)

# %% [markdown]
# ![marge.jpg](attachment:marge.jpg)

# %%
import cv2
import numpy as np

#read image 
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 22.png")
img = cv2.resize(img,(400,400))

print("shape==",img.shape)# ans shape== (600, 800, 3)
print("pixels==",img.size)# ans total number of pixels
print("datatype==",img.dtype)
print("ImageType==",type(img))


#split image - return 3 channal of a image blue red green
# print(cv2.split(img))

blue,green,red = cv2.split(img)

'''
# for 4 imgage blue green red
cv2.imshow("blue",blue)
cv2.imshow("green",green)
cv2.imshow("red",red)
cv2.imshow("Original image",img)
'''

'''marge image'''# MIXING RED BLUE GREEN

margeImage = cv2.merge((red,blue,green)) #here red before 
cv2.imshow("margeImage",margeImage)
cv2.imshow("Original image",img)


cv2.waitKey(0)
cv2.destroyAllWindows();
# Out:
# shape== (400, 400, 3)
# pixels== 480000
# datatype== uint8
# ImageType== <class 'numpy.ndarray'>

# %% [markdown]
# ### Working on pixel color values

# %%
import cv2
import numpy as np

#read image 
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 20.png")
img = cv2.resize(img,(500,400))

cv2.imshow("Original image",img)


'''access a pixel rgb value by given cordinates(x,y)'''
px = img[150,152]
print("pixel rgb value == ",px) #pixel rgb value ==  [175 202 230]


cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ### ROI(Region Of Interesrt)

# %% [markdown]
# ![crope and paste.jpg](<attachment:crope and paste.jpg>)

# %%
import cv2
import numpy as np

#read image 
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 44.png")
img = cv2.resize(img,(800,600))


#ROI 
# (350,340) (470,410) here (x1,y1),(x2,y2)
# [(y1,y2),(x1,x2)]
#y=410-340 = 70 /// x=470-350=120

roi = img[340:410,350:470]

# now data passing into image

img[340:410,470:590] = roi
img[410:480,350:470] = roi

# cv2.imshow("Original image",roi)
cv2.imshow("Original image",img)
cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ### image border

# %% [markdown]
# ![border.jpg](attachment:border.jpg)

# %%
import cv2
import numpy as np

#read image 
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 42.png")
img = cv2.resize(img,(400,300))

#create image border
brdr = cv2.copyMakeBorder(img,10,10,5,5,cv2.BORDER_CONSTANT,value=[225,0,125])
# brdr = cv2.copyMakeBorder(img,10,10,5,5,cv2.BORDER_WRAP,value=[225,0,125])

# cv2.imshow("Original image",img)
cv2.imshow("brdr image",brdr)
cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ### IMAGE Blanding

# %% [markdown]
# ![blending.jpg](attachment:blending.jpg)

# %%
import cv2
import numpy as np

#read image 
img1 = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 42.png")
img2 = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 18.png")
img1 = cv2.resize(img1,(250,250))
img2 = cv2.resize(img2,(250,250))


cv2.imshow("img1 image",img1)
cv2.imshow("img2 image",img2)

# Normal Blanding

result =   img1 +img2 #numpy addition in this we get module between vavlue
cv2.imshow("Normal Blanding image",result)

# Recommeding Blanding
result =  cv2.add(img1,img2)
cv2.imshow("Recommeding Blanding image",result)

# Recommeding Blanding add weight
# sum of bouth weight = w1+w2 = 1(max)

result =  cv2.addWeighted(img1,0.4,img2,0.6,0)
cv2.imshow("add weight Recommeding Blanding image",result)


cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ## Image blending Project using Trackbars

# %% [markdown]
# ![blending app.jpg](<attachment:blending app.jpg>)

# %%
import cv2
import numpy as np

#read image 
img1 = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 42.png")
img2 = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 18.png")
img1 = cv2.resize(img1,(500,450))
img2 = cv2.resize(img2,(500,450))

# cv2.imshow("img1 image",img1)
# cv2.imshow("img2 image",img2)


def blend(x):
    pass

img = np.zeros((400,400,3),np.uint8)
cv2.namedWindow("win") #create Trackbar
cv2.createTrackbar("alpha","win",1,100,blend)

switch = "0 : OFF \n 1 : ON" #create switch for invoke value the traackbars
cv2.createTrackbar(switch,"win",0,1,blend)

while True:
    s = cv2.getTrackbarPos(switch,"win")
    a = cv2.getTrackbarPos("alpha","win")
    n = float(a/100)
    # print(n)
    if s==0:
        dst = img[:]
    else:
        dst = cv2.addWeighted(img1,1-n,img2,n,0 )
        cv2.putText(dst,str(a),(20,50),cv2.FONT_ITALIC,2,(0,125,225),2)

    cv2.imshow("dst",dst)

    k = cv2.waitKey(1) & 0xFF
    if k == 27:
     break

cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ## BITWISE OPERATOPN ON IMAGE

# %% [markdown]
# #### AND OR NOT XOR

# %% [markdown]
# ![Bitwise.jpg](attachment:Bitwise.jpg)

# %%
import cv2
import numpy as np

img1 = np.zeros((380,380,3),np.uint8)
img1 = cv2.rectangle(img1,(50,100),(200,250),(255, 3, 251),-1)



img2 = np.zeros((380,380,3),np.uint8)
img2 = cv2.rectangle(img2,(100,200),(300,350),(252, 186, 3),-1)


# cv2.imshow("img1 image",img1)
# cv2.imshow("img2 image",img2)

# AND
bitAnd  = cv2.bitwise_and(img2,img1)
bitOR = cv2.bitwise_or(img2,img1)
bitNOT = cv2.bitwise_not(img1)
bitXOR = cv2.bitwise_xor(img1,img2)

cv2.imshow("And",bitAnd)
cv2.imshow("OR",bitOR)
cv2.imshow("NOT",bitNOT)
cv2.imshow("XOR",bitXOR)



cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ### Color Detection or Object tracing

# %% [markdown]
# ## HSV color scape // HUE Saturation Value

# %% [markdown]
# ![bol.jpg](attachment:bol.jpg)

# %%
import cv2
import numpy as np

#read image 
frame = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color.jpg")
frame = cv2.resize(frame,(400,300))

while True:
    hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    upper_value = np.array([175,252,172])  #rgb-172, 252, 175
    lower_value = np.array([107,176,0]) #rgb -0, 176, 7
    # create filter or mask
    mask = cv2.inRange(hsv,lower_value,upper_value)

    #filter mask with Bitwise Operation
    res = cv2.bitwise_or(frame, frame, mask= mask)

    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("res",res)

    k = cv2.waitKey(1) & 0xFF
    if k == 27:
     break

cv2.destroyAllWindows();

# %% [markdown]
# ## Color Detecting

# %% [markdown]
# ### Extrac color from image with Trackbar

# %% [markdown]
# ![masking.jpg](attachment:masking.jpg)

# %% [markdown]
# ![masking 2.jpg](<attachment:masking 2.jpg>)

# %%
import cv2
import numpy as np

#read image 
frame = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color2.jpg")
# frame = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color.jpg")
frame = cv2.resize(frame,(400,300))

def nothing(x):
    pass

cv2.namedWindow("Color Adjustments")


#creating for HEU  Lower Bar
cv2.createTrackbar("Lower_H","Color Adjustments",0,255,nothing)
cv2.createTrackbar("Lower_S","Color Adjustments",0,255,nothing)
cv2.createTrackbar("Lower_V","Color Adjustments",0,255,nothing)

#creating for HEU  Upper Bar

cv2.createTrackbar("Upper_H","Color Adjustments",255,255,nothing)
cv2.createTrackbar("Upper_S","Color Adjustments",255,255,nothing)
cv2.createTrackbar("Upper_V","Color Adjustments",255,255,nothing)

while True:
    hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    #Getting for HEU  Lower Bar
    lower_H = cv2.getTrackbarPos("Lower_H","Color Adjustments")
    lower_S = cv2.getTrackbarPos("Lower_S","Color Adjustments")
    lower_V = cv2.getTrackbarPos("Lower_V","Color Adjustments")

    #Getting for HEU  Upper Bar
    
    upper_H = cv2.getTrackbarPos("Upper_H","Color Adjustments")
    upper_S = cv2.getTrackbarPos("Upper_S","Color Adjustments")
    upper_V = cv2.getTrackbarPos("Upper_V","Color Adjustments")

    lower_Bound = np.array([lower_H,lower_S,lower_V])
    upper_Bound = np.array([upper_H,upper_S,upper_V])

   # create filter or mask
    mask = cv2.inRange(hsv,lower_Bound,upper_Bound)

    #filter mask with Bitwise Operation
    res = cv2.bitwise_and(frame, frame, mask = mask)



    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("result",res)

    k = cv2.waitKey(1) & 0xFF # exit press Esc
    if k == 27:
     break

cv2.destroyAllWindows();

# %% [markdown]
# ### Color Detecting from Webcam

# %% [markdown]
# ![Screenshot_3.jpg](attachment:Screenshot_3.jpg)

# %%
import cv2
import numpy as np


cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)


def nothing(x):
    pass

cv2.namedWindow("Color Adjustments")

#creating for HEU  Lower Bar
cv2.createTrackbar("Lower_H","Color Adjustments",0,255,nothing)
cv2.createTrackbar("Lower_S","Color Adjustments",0,255,nothing)
cv2.createTrackbar("Lower_V","Color Adjustments",0,255,nothing)

#creating for HEU  Upper Bar
cv2.createTrackbar("Upper_H","Color Adjustments",255,255,nothing)
cv2.createTrackbar("Upper_S","Color Adjustments",255,255,nothing)
cv2.createTrackbar("Upper_V","Color Adjustments",255,255,nothing)

while True:
    _,frame = cap.read()
    frame = cv2.resize(frame,(400,400))

    hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    #Getting for HEU  Lower Bar
    lower_H = cv2.getTrackbarPos("Lower_H","Color Adjustments")
    lower_S = cv2.getTrackbarPos("Lower_S","Color Adjustments")
    lower_V = cv2.getTrackbarPos("Lower_V","Color Adjustments")

    #Getting for HEU  Upper Bar
    
    upper_H = cv2.getTrackbarPos("Upper_H","Color Adjustments")
    upper_S = cv2.getTrackbarPos("Upper_S","Color Adjustments")
    upper_V = cv2.getTrackbarPos("Upper_V","Color Adjustments")

    lower_Bound = np.array([lower_H,lower_S,lower_V])
    upper_Bound = np.array([upper_H,upper_S,upper_V])

   # create filter or mask
    mask = cv2.inRange(hsv,lower_Bound,upper_Bound)

    #filter mask with Bitwise Operation
    res = cv2.bitwise_and(frame, frame, mask = mask)



    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("result",res)

    k = cv2.waitKey(1) & 0xFF # exit press Esc
    if k == 27:
     break

cv2.destroyAllWindows();

# %% [markdown]
# ## Thresholding
# #### In image processing thresholding is the simplest method of segmentating Images

# %% [markdown]
# ##### thresholding 3 types
# ##### simple , adaptive ,

# %% [markdown]
# ## simple thresholding

# %% [markdown]
# ![simple thresholding.jpg](<attachment:simple thresholding.jpg>)

# %%
# simple thresholding

import cv2
import numpy as np

#read image 
# img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color3.jpg  ",0)
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color2.jpg",0)
img = cv2.resize(img,(400,200))

'''simple thresholding(img,pixel_thresh,_max_thresh_pixel,style)'''

_, th1 = cv2.threshold(img,50,225,cv2.THRESH_BINARY)
_, th2 = cv2.threshold(img,50,225,cv2.THRESH_BINARY_INV)
_, th3 = cv2.threshold(img,50,225,cv2.THRESH_TRUNC)
_, th4 = cv2.threshold(img,50,225,cv2.THRESH_TOZERO)


cv2.imshow("img",img)
cv2.imshow("THRESH_BINARY ",th1)
cv2.imshow("THRESH_BINARY_INV ",th2)
cv2.imshow("THRESH_TRUNC ",th3)
cv2.imshow("THRESH_TOZERO ",th4)


cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ## Adaptive thresholding
# ##

# %%
import cv2
import numpy as np

#read image 
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color4.jpg",0)
img = cv2.resize(img,(400,300))

'''Adaptive thresholding(img,pixel_thresh,_max_thresh_pixel,methd,style,no._of_pixel,contact_mean)'''

_, th1 = cv2.threshold(img,50,225,cv2.THRESH_BINARY)#simple thrasholding
th2 = cv2.adaptiveThreshold(img,225,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)#Adaptive thrasholding




cv2.imshow("img",img)
cv2.imshow("simple THRESH_BINARY ",th1)
cv2.imshow("ADAPTIVE_THRESH_MEAN_C ",th2)



cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ## Background Subtruction

# %%
import cv2
import numpy as np

#read image 
img1 = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 28.png")
img2 = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 6.png")
img1 = cv2.resize(img1,(700,600))
img2 = cv2.resize(img2,(450,400))# it should be small




# watch the shape of a image
row,col,channel = img2.shape
print(row,col,channel ) # np array image show in array types

#roi ==
roi = img1[0:row,0:col]


#now creating mask for img2
img_gry = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY,0)


#create mask using threshold 
_, mask = cv2.threshold(img_gry,100,150,cv2.THRESH_BINARY)


#remove bg
mask_inv = cv2.bitwise_not(mask)

#put mask into roi
img1_bg= cv2.bitwise_and(roi,roi,mask=mask_inv)

#take only region of figure form original image
img2_fg = cv2.bitwise_and(img2,img2,mask=mask)


res = cv2.add(img1_bg,img2_fg)

final = img1
final [0:row,0:col] = res


# cv2.imshow("img",img1)
# cv2.imshow("img2",img2)
cv2.imshow("roi",roi)
cv2.imshow("img_gry",mask)
cv2.imshow("img2_fg",img2_fg)
cv2.imshow("img2_inv",mask_inv)
cv2.imshow("img1_bg",img1_bg)
cv2.imshow("res",res)
cv2.imshow("final",final)


cv2.waitKey(0)
cv2.destroyAllWindows();
# Out:
# 400 450 3

# %% [markdown]
# ## -----------Morphological Transformations-----------------------
# ### it is simple operations based on the image shape
# ### it needs two inputs 1)-originak image 2) struucturing element
# ### Two basic Morphological Transformation are 1) - Erosion and 2) Dilation

# %% [markdown]
# ![morfe.png](attachment:morfe.png)

# %%
import cv2
import numpy as np

#Erosion---
#it erodes away the boundaries of foreground object

#kernal slides through all the image and all the pixel 
#from the original image conside 1 only if kernal's pixel is 1


img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\asset 21.png",0)
img = cv2.resize(img,(400,300))


_, mask = cv2.threshold(img,50,225,cv2.THRESH_BINARY_INV)

kernel = np.ones((1,1),np.uint8)# 1x1 kernel with full of ones. 
Erosion = cv2.erode(mask,kernel) #optional parameters   iterations = 2


#Dilation -- 
#It is just opposite of erosion.
#Here, a pixel element is ‘1’ if atleast one pixel under the kernel is ‘1’
#So it inc. the white region in the image or size of foreground object in.
#Normally, in cases like noise removal, erosion is followed by dilation. 
#Because, erosion removes white noises, but it also shrinks our object. 

kernel = np.ones((1,1),np.uint8)# 1x1  kernel with full of ones.  
Dilation = cv2.dilate(mask,kernel) #iterations = 2 (optional parameters) iterations = 2


#if you want then plot it
from matplotlib import pyplot as plt
titles = ["img","mask","erosion","dilation"]
images = [img,mask,Erosion,Dilation]
for i in range(4):
    # plt.subplot(2, 2, i+1), plt.imshow(images[i], 'gray')# 2row 2 col
    plt.subplot(1,4, i+1), plt.imshow(images[i], 'gray') # 1row 1col
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()


# cv2.imshow("res",img)
# cv2.imshow("Mask",mask)
# cv2.imshow("Erosion",Erosion)
# cv2.imshow("Dilation",Dilation)


cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ### Morphological Transformations opening and closing

# %% [markdown]
# ![opening closing.jpg](<attachment:opening closing.jpg>)

# %%
import cv2
import numpy as np


img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color5.jpg",0)
img = cv2.resize(img,(400,300))

#opening

_, mask = cv2.threshold(img,200,225,cv2.THRESH_BINARY_INV)
kernel = np.ones((1,1),np.uint8)# 3x3 kernel with full of ones. 
o =cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernel)


cv2.imshow("res",img)
cv2.imshow("opening",o)



#closing

kernel = np.ones((1,1),np.uint8)# 3x3 kernel with full of ones. 
c =cv2.morphologyEx(mask,cv2.MORPH_CLOSE,kernel)

cv2.imshow("closingc",c)

cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ## Image Smoothinig or Bluring
# ### Image Smoothing or bluring is most common used operation in Image Processing.
# ### It is use to remove noise from the images.
# ### There are so many filter  which is use for smoothing the image.
# ### There are LOW Pass Filter(LPS) which use to remove Noise from the images.
# ### There are High Pass Filter which use to detect and finding edges in an image.

# %% [markdown]
# ![image smothing.png](<attachment:image smothing.png>)

# %%
import cv2
import numpy as np

#like , homogeneous,blur(averaging),homogeneous,median,bilateral

img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color10.jpg")
img = cv2.resize(img,(400,400))

cv2.imshow("img",img)

#define a kernal for homogeneous function
kernel = np.ones((5,5),np.float32)/25

#FILTER NUMBER -----1
#this filter  work like, each output pixel is the mean of its kernal neigbours
#it is aka homogeneous filter in this all pixel contribute with equal weight.
#kernal is a small shape or matrix which we apply on image.
#in this filter kernal is [(1/kernal(h,w))*kernal]   
h_filter = cv2.filter2D(img,-1,kernel) # -1 is desired depth
cv2.imshow("homogeneous==",h_filter)


#FILtER NUMBER 2-----
#blur method or averaging
#takes the avg of all the pixels under kernel area and 
#replaces the central element with this average..
blur = cv2.blur(img,(8,8)) #here we have image and kernel as parameter
cv2.imshow("blur==",blur)


#Filter Number 3------
#Gaussian Filter -here it using different weight kernel,in  row as well as col.
#means side values are small then centre .It manage distance b/w value of pixel.

gau= cv2.GaussianBlur(img,(5,5),0) #here 0 is sigma x value
cv2.imshow("gau blur=",gau)

#Filter Number 4--
#Median Filter --computes the median of all the pixels under the 
#kernel window and the central pixel is replaced with this median value.
# This is highly effective in removing salt-and-pepper noise. 
#here kernal size must be odd except one
med = cv2.medianBlur(img,5)
cv2.imshow("median filter",med)

#bilateral filter --- is highly effective at noise removal while preserving edges.
#It work like gaussian filter but more focus on edges
#it is slow as compare with other filters
#argument (img, neigbour_pixel_diameter,sigma_color,sigma_space)
bi_f = cv2.bilateralFilter(img,9,75,75)
cv2.imshow("bi_f",bi_f)


#Now plot all the images on graph
titles = ["original_image","homo","blur","gauss","med","bi_f"]
images = [img,h_filter,blur,gau,med,bi_f]

#if you want then plot it
from matplotlib import pyplot as plt
for i in range(6):
    plt.subplot(2, 3, i+1), 
    plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()


cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ## Image Greadent
#
# ### It is a directional change in the color or intensity in an image.
# ### It is most important part to find inormation from image
# ### Like finding edges within the images.
# ### There are various methods to find image gradient.
# ### These are - Laplacian Derivatives,SobelX and SobelY.
# ### All these functions have diff. mathematical approach to get result.
# ### All load image in the gray scale

# %% [markdown]
# ![image greadent.jpg](<attachment:image greadent.jpg>)

# %%
import cv2
import numpy as np

img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color13.jpg",0)# for gray
img = cv2.resize(img,(400,300))

cv2.imshow("img",img)

#Laplacian Derivative---It calculate laplace derivate
#parameter(img,data_type for -ve val,ksize)
#kernal size must be odd
lap = cv2.Laplacian(img,cv2.CV_64F,ksize =3) #also pass kernal size
lap = np.uint8(np.absolute(lap))

cv2.imshow("lap",lap)
#Sobel operation - 
# is a joint Gausssian smoothing plus differentiation operation, 
#so it is more  resistant to noise
#This is use for x and y bth
#parameter (img,type for -ve val,x = 1,y = 0,ksize)
#Sobel X focus on vertical lines
#Sobel y focus on horizontal lines

sobelX = cv2.Sobel(img,cv2.CV_64F,1,0,ksize = 3) #here 1 means x direction
sobelY = cv2.Sobel(img,cv2.CV_64F,0,1,ksize = 3) #here 1 means y direction

sobelX = np.uint8(np.absolute(sobelX))
sobelY= np.uint8(np.absolute(sobelY))

#finally combine sobelX and sobelY togather
sobelcombine = cv2.bitwise_or(sobelX,sobelY)

cv2.imshow("SobelX===",sobelX)
cv2.imshow("SobelY==",sobelY)
cv2.imshow("sobelcombine",sobelcombine)


cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ### Canny Edge
#
# ### Canny Edge Detection using OpenCV
# ### Canny Edge Detection is a popular edge detection approach.
# ### It is use  multi-stage algorithm to detect a edges.
# ### It was developed by John F. Canny in 1986.
# ### This approach combine with 5 steps.
#
# ### 1) -  NOise reduction(gauss)), 2) -Gradient calculation( ,
# ### 3) - Non-maximum suppresson, 4) - Double Threshold,
# ### 5) - Edge Tracking by Hysteresis

# %% [markdown]
# ![canny.jpg](attachment:canny.jpg)

# %%
import cv2
import numpy as np

# img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color18.jpg",0)# for gray

img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color10.jpg")
img = cv2.resize(img,(400,300))
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#canny(img,thresh1,thres2)thresh 1 and thresh2 at different lvl
canny = cv2.Canny(img_gray,100,150) #lower and upper threshold

cv2.imshow("Original img",img)
cv2.imshow("img_gray",img_gray)
cv2.imshow("canny image",canny)


cv2.waitKey(0)
cv2.destroyAllWindows();

# %% [markdown]
# ### using trackbars ---same code

# %% [markdown]
# ![canny with trackbar.jpg](<attachment:canny with trackbar.jpg>)

# %%
import cv2
import numpy as np

# img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color18.jpg",0)# for gray

img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color11.jpg")
img = cv2.resize(img,(600,500))
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# cv2.imshow("img_gray",img_gray)

def nothing(x):
    pass

cv2.namedWindow("Canny")
cv2.createTrackbar("Threshold", "Canny", 0, 255, nothing)

while True:
    a = cv2.getTrackbarPos('Threshold','Canny')
    
    print(a)
    res = cv2.Canny(img_gray,a,255)
    cv2.imshow("Canny",res)
    k=cv2.waitKey(1) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()

# %% [markdown]
# ## Image Pyramid
# ### We use Image Pyramid because somethimes we work on same imge but different resolution.e.g. searching face, ### eye in an image and it vary image to image so in this case we create a set of images with diff. resolution ### which is called pyramid. We also use these pyramids to blends the images.
#
# ### There are two types of Image Pyramid-
# ### 1) Gaussian Pyramid and 2) Laplacian Pyramids

# %% [markdown]
# ![pyramid.jpg](attachment:pyramid.jpg)

# %%
import cv2
import numpy as np


img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color11.jpg")
img = cv2.resize(img,(400,400))

#Gaussian Pyramid Have 2 function-1) cv2.pyrUp(),2)-cv2.pyrDown()
#pyrdown----
pd1 = cv2.pyrDown(img)

pu1 = cv2.pyrUp(pd1)

cv2.imshow("Original img",img)
cv2.imshow("Pyramid down img",pd1)
cv2.imshow("Pyramid up img",pu1)


cv2.waitKey(0)
cv2.destroyAllWindows()


#using loop to generate pyramid
#load image into gray scale
"""
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color11.jpg")
img = cv2.resize(img,(700,700))

img1 = img.copy()
data = [img1]

for i in range(4):
    img1 = cv2.pyrDown(img1)
    data.append(img1)
    cv2.imshow("res"+str(i),img1)

cv2.imshow("original==",img)
cv2.waitKey(0)
cv2.destroyAllWindows()    

"""

# %% [markdown]
# # Contours and its Introduction
#
# ## Contours -
# ## Contours can be explained simply as a curve joining all the continuous points
# ## (along the boundary), having same color or intensity.
#
# ## The contours are a useful tool for shape analysis and object detection and recognition
#
# ## For better accuracy, use binary images and also apply edge detection before
#
# ## finding countours.
#
# ## findCountour function manipulate original imge so copy it before proceeding.
# ## findContour is like finding white object from black background.
# ## so you must turn image in white and background is black.

# %% [markdown]
# ![contors.jpg](attachment:contors.jpg)

# %%
import cv2
import numpy as np


img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color.jpg")
img = cv2.resize(img,(400,400))
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(img_gray,150,225,0)# binary image convert

#findcontour(img,contour_retrival_mode,method)
cnts,hier = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

#Here cnts is a list of contours. ANd each contour is an array with x, y cordinate   
#hier variable called hierarchy and it contain image information.
print("Number of contour==",cnts,"\ntotal contour==",len(cnts))
print("Hierarchy==\n",hier)

#drawcontour(img,cnts,id of contour,color,thickness)#here if we draw all
#contour just pass -1
#Draw the contours
img = cv2.drawContours(img,cnts,-1,(255, 0, 0),3)

for c in cnts:
    # compute the center of the contour
    #an image moment is a certain particular weighted average (moment) of the image pixels
    M = cv2.moments(c)
    print("M==",M)
    cX = int(M["m10"] / M["m00"])
    cY = int(M["m01"] / M["m00"])
    # draw the contour and center of the shape on the image
    cv2.drawContours(img, [c], -1, (0, 255, 0), 2)
    cv2.circle(img, (cX, cY), 7, (255, 255, 255), -1)
    cv2.putText(img, "center", (cX - 20, cY - 20),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

cv2.imshow("Original img",img)
cv2.imshow("img_gray img",img_gray)
cv2.imshow("thresh img",thresh)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Contours Functions

# %% [markdown]
# ![Screenshot_2.jpg](attachment:Screenshot_2.jpg)

# %%
import cv2
import numpy as np

img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color22.jpg")
img = cv2.resize(img,(400,400))
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(img_gray,150,225,0)# binary image convert

#findcontour(img,contour_retrival_mode,method)
cnts,hier = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
#Here cnts is a list of contours. ANd each contour is an array with x, y cordinate   
#hier variable called hierarchy and it contain image information.
print("Number of contour==",cnts,"\ntotal contour==",len(cnts))
#print("Hierarchy==\n",hier)

# draw conturs
img = cv2.drawContours(img,cnts,-1,(255, 0, 0),3)


    
cv2.imshow("original===",img)
cv2.imshow("gray==",img_gray)
cv2.imshow("thresh==",thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### #-------------Contour Area , Approximation and Convex hull

# %% [markdown]
# ![Screenshot_1.jpg](attachment:Screenshot_1.jpg)

# %%
import cv2
import numpy as np

#Find countour area , aprroximation and convex hull
img = cv2.imread("C:\\Users\\ripon\\Downloads\\phote assets\\multiple color23.png")
img = cv2.resize(img,(450,400))
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

ret,thresh = cv2.threshold(img1,150,255,cv2.THRESH_BINARY_INV)

#findcontour(img,contour_retrival_mode,method)
cnts,hier = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
#Here cnts is a list of contours. ANd each contour is an array with x, y cordinate   
#hier variable called hierarchy and it contain image information.
print("Number of contour==",cnts,"\ntotal contour==",len(cnts))
#print("Hierarchy==\n",hier)

area1 = []
# loop over the contours
for c in cnts:
    # compute the center of the contour
    #an image moment is a certain particular weighted average (moment) of the image pixels
    M = cv2.moments(c)
    #print("M==",M)
    cX = int(M["m10"] / M["m00"])
    cY = int(M["m01"] / M["m00"])
    #find area of contour
    area = cv2.contourArea(c)
    area1.append(area)
    
    if area<10000:
        #contour Approx -  it is use to approx shape with less number of vertices
        epsilon = 0.1*cv2.arcLength(c,True) #arc lenght take contour and return its perimeter
        data= cv2.approxPolyDP(c,epsilon,True)
        #Convexhull is used to provide proper contours convexity.
        
        hull = cv2.convexHull(data)
        
        x,y,w,h = cv2.boundingRect(hull)
        img = cv2.rectangle(img,(x,y),(x+w,y+h),(123,123,43),5)
 
    # draw the contour and center of the shape on the image
    cv2.drawContours(img, [c], -1, (50, 100, 50), 2)
    cv2.circle(img, (cX, cY), 7, (255, 255, 255), -1)
    cv2.putText(img, "center", (cX - 20, cY - 20),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
    
    
cv2.imshow("original===",img)
cv2.imshow("gray==",img1)
cv2.imshow("thresh==",thresh)
cv2.waitKey(0)
